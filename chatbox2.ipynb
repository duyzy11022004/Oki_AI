# %%
# !pip install -q sentence-transformers transformers chromadb gradio langchain ollama
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.31.1 which is incompatible.

# %%
# !pip install chromadb
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/19.5 MB 8.4 MB/s eta 0:00:03
#    ------ --------------------------------- 3.1/19.5 MB 8.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.9/19.5 MB 6.3 MB/s eta 0:00:03
#    --------- ------------------------------ 4.5/19.5 MB 5.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 5.0/19.5 MB 4.8 MB/s eta 0:00:04
#    ------------ --------------------------- 6.3/19.5 MB 5.1 MB/s eta 0:00:03
#    ------------- -------------------------- 6.8/19.5 MB 4.6 MB/s eta 0:00:03
# ...

# %%
# !pip install sentence-transformers

# %%
# !pip install -U sentence-transformers transformers torch accelerate

# %%
# !pip uninstall transformers sentence-transformers -y
# !pip install -U pip
# !pip install -U sentence-transformers
# Out:
# Found existing installation: transformers 4.53.2
# Uninstalling transformers-4.53.2:
#   Successfully uninstalled transformers-4.53.2
# Found existing installation: sentence-transformers 5.0.0
# Uninstalling sentence-transformers-5.0.0:
#   Successfully uninstalled sentence-transformers-5.0.0
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
# ...

# %%
# !pip install torch
# !pip install transformers==4.40.2
# !pip install sentence-transformers
# Out:
# ...
# error: uninstall-no-record-file
#
# × Cannot uninstall tokenizers None
# ╰─> The package's contents are unknown: no RECORD file was found for tokenizers.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps tokenizers==0.21.2
# ...
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.0 MB ? eta -:--:--
# ...

# %%
import chromadb
from sentence_transformers import SentenceTransformer
from langchain.llms import Ollama
from tokenizers import Tokenizer
import uuid

# Khởi tạo mô hình embedding + mô hình sinh câu trả lời
embed_model = SentenceTransformer("all-MiniLM-L6-v2")
llm = Ollama(model="qwen3:4b")

# Vector DB
chroma_client = chromadb.Client()
collection = chroma_client.get_or_create_collection(name="memory")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 import chromadb
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 from langchain.llms import Ollama
#       4 from tokenizers import Tokenizer
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 __version__ = "5.0.0"
#       4 __MODEL_HUB_ORGANIZATION__ = "sentence-transformers"
#       6 import importlib
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
# ...

# %%
# !pip show sentence-transformers
# Out:
# Name: sentence-transformers
# Version: 2.2.2
# Summary: Multilingual text embeddings
# Home-page: https://github.com/UKPLab/sentence-transformers
# Author: Nils Reimers
# Author-email: info@nils-reimers.de
# License: Apache License 2.0
# Location: C:\Users\DELL\anaconda3\Lib\site-packages
# Requires: huggingface-hub, nltk, numpy, scikit-learn, scipy, sentencepiece, torch, torchvision, tqdm, transformers
# Required-by:

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DELL\anaconda3\python.exe

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
print(model.encode("Xin chào")[:5])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 model = SentenceTransformer("all-MiniLM-L6-v2")
#       3 print(model.encode("Xin chào")[:5])
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 __version__ = "5.0.0"
#       4 __MODEL_HUB_ORGANIZATION__ = "sentence-transformers"
#       6 import importlib
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
# ...

# %%
# !pip install huggingface_hub==0.20.3
# Out:
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.30.2
#     Uninstalling huggingface-hub-0.30.2:
#       Successfully uninstalled huggingface-hub-0.30.2
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# accelerate 1.9.0 requires huggingface_hub>=0.21.0, but you have huggingface-hub 0.20.3 which is incompatible.
# datasets 4.0.0 requires huggingface-hub>=0.24.0, but you have huggingface-hub 0.20.3 which is incompatible.
# gradio 5.29.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.20.3 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 0.20.3 which is incompatible.

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("all-MiniLM-L6-v2")
print("✅ Tải thành công!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 model = SentenceTransformer("all-MiniLM-L6-v2")
#       3 print("✅ Tải thành công!")
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 __version__ = "5.0.0"
#       4 __MODEL_HUB_ORGANIZATION__ = "sentence-transformers"
#       6 import importlib
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
# ...
